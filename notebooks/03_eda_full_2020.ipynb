# %% [markdown]
# # EDA du dataset optimized_2020.parquet

# %% [markdown]
# ## Descriptif des colonnes du fichier csv
# | Colonne                        | Description                                                                 |
# |-------------------------------|-----------------------------------------------------------------------------|
# | `id_mutation`                 | Identifiant de mutation (non stable, sert à grouper les lignes)            |
# | `date_mutation`              | Date de la mutation au format ISO-8601 (YYYY-MM-DD)                        |
# | `numero_disposition`         | Numéro de disposition                                                       |
# | `nature_mutation`            | Nature de la mutation                                                       |
# | `valeur_fonciere`            | Valeur foncière (séparateur décimal = point)                               |
# | `adresse_numero`             | Numéro de l'adresse                                                         |
# | `adresse_suffixe`            | Suffixe du numéro de l'adresse (B, T, Q)                                   |
# | `adresse_code_voie`          | Code FANTOIR de la voie (4 caractères)                                     |
# | `adresse_nom_voie`           | Nom de la voie de l'adresse                                                |
# | `code_postal`                | Code postal (5 caractères)                                                 |
# | `code_commune`               | Code commune INSEE (5 caractères)                                          |
# | `nom_commune`                | Nom de la commune (accentué)                                               |
# | `ancien_code_commune`       | Ancien code commune INSEE (si différent lors de la mutation)               |
# | `ancien_nom_commune`        | Ancien nom de la commune (si différent lors de la mutation)                |
# | `code_departement`          | Code département INSEE (2 ou 3 caractères)                                  |
# | `id_parcelle`                | Identifiant de parcelle (14 caractères)                                    |
# | `ancien_id_parcelle`        | Ancien identifiant de parcelle (si différent lors de la mutation)          |
# | `numero_volume`             | Numéro de volume                                                            |
# | `lot_1_numero`              | Numéro du lot 1                                                             |
# | `lot_1_surface_carrez`      | Surface Carrez du lot 1                                                     |
# | `lot_2_numero`              | Numéro du lot 2                                                             |
# | `lot_2_surface_carrez`      | Surface Carrez du lot 2                                                     |
# | `lot_3_numero`              | Numéro du lot 3                                                             |
# | `lot_3_surface_carrez`      | Surface Carrez du lot 3                                                     |
# | `lot_4_numero`              | Numéro du lot 4                                                             |
# | `lot_4_surface_carrez`      | Surface Carrez du lot 4                                                     |
# | `lot_5_numero`              | Numéro du lot 5                                                             |
# | `lot_5_surface_carrez`      | Surface Carrez du lot 5                                                     |
# | `nombre_lots`               | Nombre de lots                                                              |
# | `code_type_local`           | Code de type de local                                                       |
# | `type_local`                | Libellé du type de local                                                    |
# | `surface_reelle_bati`       | Surface réelle du bâti                                                      |
# | `nombre_pieces_principales`| Nombre de pièces principales                                                |
# | `code_nature_culture`       | Code de nature de culture                                                   |
# | `nature_culture`            | Libellé de nature de culture                                                |
# | `code_nature_culture_speciale` | Code de nature de culture spéciale                                       |
# | `nature_culture_speciale`   | Libellé de nature de culture spéciale                                       |
# | `surface_terrain`           | Surface du terrain                                                          |
# | `longitude`                 | Longitude du centre de la parcelle concernée (WGS-84)                       |
# | `latitude`                  | Latitude du centre de la parcelle concernée (WGS-84)                        |

# %%
# 📦 Imports
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 📄 Chargement du fichier optimisé
df = pd.read_parquet("../data/raw/optimized_2020.parquet")
print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (3522416, 40)
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2020-1    2020-01-07                   1           Vente
# 1      2020-2    2020-01-02                   1           Vente
# 2      2020-2    2020-01-02                   1           Vente
# 3      2020-2    2020-01-02                   1           Vente
# 4      2020-2    2020-01-02                   1           Vente
#
#    valeur_fonciere  adresse_numero adresse_suffixe        adresse_nom_voie  \
# 0           8000.0             NaN             nan                FORTUNAT
# 1           2175.0             NaN             nan  TERRES DES CINQ SAULES
# 2           2175.0             NaN             nan      BOIS DU CHAMP RION
# 3           2175.0             NaN             nan             EN COROBERT
# 4           2175.0             NaN             nan  TERRES DES CINQ SAULES
#
#   adresse_code_voie  code_postal code_commune nom_commune code_departement  \
# 0              B063       1250.0        01072   Ceyzériat               01
# 1              B124       1290.0        01203        Laiz               01
# 2              B006       1290.0        01203        Laiz               01
# 3              B025       1290.0        01203        Laiz               01
# 4              B124       1290.0        01203        Laiz               01
#
#    ancien_code_commune ancien_nom_commune     id_parcelle ancien_id_parcelle  \
# 0                  NaN                nan  01072000AK0216                nan
# 1                  NaN                nan  012030000B0004                nan
# 2                  NaN                nan  012030000B0173                nan
# 3                  NaN                nan  012030000B0477                nan
# 4                  NaN                nan  012030000C0068                nan
#
#   numero_volume lot1_numero  lot1_surface_carrez lot2_numero  \
# 0           nan         nan                  NaN         nan
# 1           nan         nan                  NaN         nan
# 2           nan         nan                  NaN         nan
# 3           nan         nan                  NaN         nan
# 4           nan         nan                  NaN         nan
#
#    lot2_surface_carrez lot3_numero  lot3_surface_carrez  lot4_numero  \
# 0                  NaN         nan                  NaN          NaN
# 1                  NaN         nan                  NaN          NaN
# 2                  NaN         nan                  NaN          NaN
# 3                  NaN         nan                  NaN          NaN
# 4                  NaN         nan                  NaN          NaN
#
#    lot4_surface_carrez  lot5_numero  lot5_surface_carrez  nombre_lots  \
# 0                  NaN          NaN                  NaN            0
# 1                  NaN          NaN                  NaN            0
# 2                  NaN          NaN                  NaN            0
# 3                  NaN          NaN                  NaN            0
# 4                  NaN          NaN                  NaN            0
#
#    code_type_local type_local  surface_reelle_bati  nombre_pieces_principales  \
# 0              NaN        nan                  NaN                        NaN
# 1              NaN        nan                  NaN                        NaN
# 2              NaN        nan                  NaN                        NaN
# 3              NaN        nan                  NaN                        NaN
# 4              NaN        nan                  NaN                        NaN
#
#   code_nature_culture   nature_culture code_nature_culture_speciale  \
# 0                   T           terres                          nan
# 1                  BT  taillis simples                          nan
# 2                   T           terres                          nan
# 3                   T           terres                          nan
# 4                   T           terres                          nan
#
#   nature_culture_speciale  surface_terrain  longitude   latitude
# 0                     nan           1061.0   5.323532  46.171940
# 1                     nan             85.0   4.893454  46.251858
# 2                     nan           1115.0   4.900210  46.235275
# 3                     nan           1940.0   4.882112  46.246555
# 4                     nan           1148.0   4.894481  46.251842

# %%
df.describe(include='all').T
# Out:
#                                   count   unique             top     freq  \
# id_mutation                     3522416  1464983     2020-861207     9147
# date_mutation                   3522416      NaN             NaN      NaN
# numero_disposition            3522416.0      NaN             NaN      NaN
# nature_mutation                 3522416        6           Vente  3207859
# valeur_fonciere               3471748.0      NaN             NaN      NaN
# adresse_numero                2118164.0      NaN             NaN      NaN
# adresse_suffixe                 3522416       40             nan  3368133
# adresse_nom_voie                3490354   499006      LE VILLAGE    34150
# adresse_code_voie               3522416    16451             nan    32026
# code_postal                   3490247.0      NaN             NaN      NaN
# code_commune                    3522416    32749           31555    28306
# nom_commune                     3522416    30604        Toulouse    28306
# code_departement                3522416       97              59    94068
# ancien_code_commune                84.0      NaN             NaN      NaN
# ancien_nom_commune              3522416        3             nan  3522332
# id_parcelle                     3522416  2097105  71153000BH0429      943
# ancien_id_parcelle              3522416        3             nan  3522414
# numero_volume                   3522416      848             nan  3513112
# lot1_numero                     3522416     9941             nan  2418146
# lot1_surface_carrez            288391.0      NaN             NaN      NaN
# lot2_numero                     3522416     4297             nan  3282214
# lot2_surface_carrez             74871.0      NaN             NaN      NaN
# lot3_numero                     3522416     1368             nan  3481567
# lot3_surface_carrez              7513.0      NaN             NaN      NaN
# lot4_numero                     13623.0      NaN             NaN      NaN
# lot4_surface_carrez              1903.0      NaN             NaN      NaN
# lot5_numero                      6311.0      NaN             NaN      NaN
# lot5_surface_carrez               794.0      NaN             NaN      NaN
# nombre_lots                   3522416.0      NaN             NaN      NaN
# code_type_local               1984454.0      NaN             NaN      NaN
# type_local                      3522416        5             nan  1537962
# surface_reelle_bati           1425415.0      NaN             NaN      NaN
# nombre_pieces_principales     1982212.0      NaN             NaN      NaN
# code_nature_culture             3522416       28               S  1170559
# nature_culture                  3522416       28            sols  1170559
# code_nature_culture_speciale    3522416      122             nan  3368874
# nature_culture_speciale         3522416      122             nan  3368874
# surface_terrain               2402976.0      NaN             NaN      NaN
# longitude                     3412616.0      NaN             NaN      NaN
# latitude                      3412616.0      NaN             NaN      NaN
#
#                                                        mean  \
# id_mutation                                             NaN
# date_mutation                 2020-07-24 06:20:10.879806464
# numero_disposition                                 1.107519
# nature_mutation                                         NaN
# valeur_fonciere                                 872683.9375
# adresse_numero                                   766.282166
# adresse_suffixe                                         NaN
# adresse_nom_voie                                        NaN
# adresse_code_voie                                       NaN
# code_postal                                    50280.796875
# code_commune                                            NaN
# nom_commune                                             NaN
# code_departement                                        NaN
# ancien_code_commune                            15079.286133
# ancien_nom_commune                                      NaN
# id_parcelle                                             NaN
# ancien_id_parcelle                                      NaN
# numero_volume                                           NaN
# lot1_numero                                             NaN
# lot1_surface_carrez                               63.465691
# lot2_numero                                             NaN
# lot2_surface_carrez                               63.833786
# lot3_numero                                             NaN
# lot3_surface_carrez                               74.287659
# lot4_numero                                      137.605301
# lot4_surface_carrez                               88.727325
# lot5_numero                                      117.421326
# lot5_surface_carrez                              112.014992
# nombre_lots                                        0.404112
# code_type_local                                    2.049449
# type_local                                              NaN
# surface_reelle_bati                              112.834915
# nombre_pieces_principales                          2.301575
# code_nature_culture                                     NaN
# nature_culture                                          NaN
# code_nature_culture_speciale                            NaN
# nature_culture_speciale                                 NaN
# surface_terrain                                 2884.548828
# longitude                                          2.359384
# latitude                                          46.063629
#
#                                               min                  25%  \
# id_mutation                                   NaN                  NaN
# date_mutation                 2020-01-01 00:00:00  2020-05-07 00:00:00
# numero_disposition                            1.0                  1.0
# nature_mutation                               NaN                  NaN
# valeur_fonciere                              0.01              66500.0
# adresse_numero                                1.0                  8.0
# adresse_suffixe                               NaN                  NaN
# adresse_nom_voie                              NaN                  NaN
# adresse_code_voie                             NaN                  NaN
# code_postal                                1000.0              29140.0
# code_commune                                  NaN                  NaN
# nom_commune                                   NaN                  NaN
# code_departement                              NaN                  NaN
# ancien_code_commune                       14666.0              14666.0
# ancien_nom_commune                            NaN                  NaN
# id_parcelle                                   NaN                  NaN
# ancien_id_parcelle                            NaN                  NaN
# numero_volume                                 NaN                  NaN
# lot1_numero                                   NaN                  NaN
# lot1_surface_carrez                          0.01            34.810001
# lot2_numero                                   NaN                  NaN
# lot2_surface_carrez                          0.21               43.605
# lot3_numero                                   NaN                  NaN
# lot3_surface_carrez                          0.34            40.509998
# lot4_numero                                   2.0                  7.0
# lot4_surface_carrez                          0.34            35.614998
# lot5_numero                                   2.0                  8.0
# lot5_surface_carrez                           1.0              28.2325
# nombre_lots                                   0.0                  0.0
# code_type_local                               1.0                  1.0
# type_local                                    NaN                  NaN
# surface_reelle_bati                           1.0                 50.0
# nombre_pieces_principales                     0.0                  0.0
# code_nature_culture                           NaN                  NaN
# nature_culture                                NaN                  NaN
# code_nature_culture_speciale                  NaN                  NaN
# nature_culture_speciale                       NaN                  NaN
# surface_terrain                               1.0                230.0
# longitude                              -63.142002             0.272443
# latitude                               -21.385195            44.671989
#
#                                               50%                  75%  \
# id_mutation                                   NaN                  NaN
# date_mutation                 2020-07-31 00:00:00  2020-10-28 00:00:00
# numero_disposition                            1.0                  1.0
# nature_mutation                               NaN                  NaN
# valeur_fonciere                          155000.0             280000.0
# adresse_numero                               25.0                105.0
# adresse_suffixe                               NaN                  NaN
# adresse_nom_voie                              NaN                  NaN
# adresse_code_voie                             NaN                  NaN
# code_postal                               49220.0              75009.0
# code_commune                                  NaN                  NaN
# nom_commune                                   NaN                  NaN
# code_departement                              NaN                  NaN
# ancien_code_commune                       14666.0              14666.0
# ancien_nom_commune                            NaN                  NaN
# id_parcelle                                   NaN                  NaN
# ancien_id_parcelle                            NaN                  NaN
# numero_volume                                 NaN                  NaN
# lot1_numero                                   NaN                  NaN
# lot1_surface_carrez                         54.02            73.330002
# lot2_numero                                   NaN                  NaN
# lot2_surface_carrez                     61.380001            76.110001
# lot3_numero                                   NaN                  NaN
# lot3_surface_carrez                         61.93            85.830002
# lot4_numero                                  22.0                 66.0
# lot4_surface_carrez                     64.860001            96.470001
# lot5_numero                                  24.0                 71.0
# lot5_surface_carrez                     64.324997               99.445
# nombre_lots                                   0.0                  1.0
# code_type_local                               2.0                  3.0
# type_local                                    NaN                  NaN
# surface_reelle_bati                          75.0                105.0
# nombre_pieces_principales                     2.0                  4.0
# code_nature_culture                           NaN                  NaN
# nature_culture                                NaN                  NaN
# code_nature_culture_speciale                  NaN                  NaN
# nature_culture_speciale                       NaN                  NaN
# surface_terrain                             602.0               1758.0
# longitude                                 2.35146             4.597507
# latitude                                46.759686            48.689823
#
#                                               max           std
# id_mutation                                   NaN           NaN
# date_mutation                 2020-12-31 00:00:00           NaN
# numero_disposition                          272.0      1.615079
# nature_mutation                               NaN           NaN
# valeur_fonciere                       490000000.0     7779914.0
# adresse_numero                             9999.0   2086.147461
# adresse_suffixe                               NaN           NaN
# adresse_nom_voie                              NaN           NaN
# adresse_code_voie                             NaN           NaN
# code_postal                               97490.0  27360.666016
# code_commune                                  NaN           NaN
# nom_commune                                   NaN           NaN
# code_departement                              NaN           NaN
# ancien_code_commune                       49382.0   3787.826172
# ancien_nom_commune                            NaN           NaN
# id_parcelle                                   NaN           NaN
# ancien_id_parcelle                            NaN           NaN
# numero_volume                                 NaN           NaN
# lot1_numero                                   NaN           NaN
# lot1_surface_carrez                        9344.0    122.057198
# lot2_numero                                   NaN           NaN
# lot2_surface_carrez                        8110.0     72.557205
# lot3_numero                                   NaN           NaN
# lot3_surface_carrez                   6947.850098    136.613449
# lot4_numero                              103190.0   1404.996094
# lot4_surface_carrez                   6947.850098    239.666977
# lot5_numero                               20028.0    497.425659
# lot5_surface_carrez                   6947.850098    432.899353
# nombre_lots                                 150.0      0.794773
# code_type_local                               4.0      0.941407
# type_local                                    NaN           NaN
# surface_reelle_bati                      218290.0    777.898071
# nombre_pieces_principales                   109.0      2.111425
# code_nature_culture                           NaN           NaN
# nature_culture                                NaN           NaN
# code_nature_culture_speciale                  NaN           NaN
# nature_culture_speciale                       NaN           NaN
# surface_terrain                        10723091.0  16580.738281
# longitude                               55.829227      6.543112
# latitude                                51.086452      6.221399

# %%
# Taux de valeurs manquantes
(df.isnull().mean() * 100).sort_values(ascending=False).head(20)
# Out:
# ancien_code_commune          99.997615
# lot5_surface_carrez          99.977459
# lot4_surface_carrez          99.945975
# lot5_numero                  99.820833
# lot3_surface_carrez          99.786709
# lot4_numero                  99.613248
# lot2_surface_carrez          97.874442
# lot1_surface_carrez          91.812693
# surface_reelle_bati          59.533031
# nombre_pieces_principales    43.725784
# code_type_local              43.662134
# adresse_numero               39.866160
# surface_terrain              31.780460
# latitude                      3.117179
# longitude                     3.117179
# valeur_fonciere               1.438445
# code_postal                   0.913265
# adresse_nom_voie              0.910228
# adresse_suffixe               0.000000
# nature_mutation               0.000000
# dtype: float64

# %% [markdown]
# ## Analyse des valeurs manquantes
# 1. Colonnes très peu renseignées (> 90%)
#
# | Colonne                                                     | Taux de NaN | Action recommandée                                             |
# | ----------------------------------------------------------- | ----------- | -------------------------------------------------------------- |
# | `ancien_code_commune`, `lotX_surface_carrez`, `lotX_numero` | > 90 %      | **À supprimer** |
#
# 2. Colonnes partiellement manquantes (10% à 60%)
#
# | Colonne                             | Taux de NaN | Action                                                                    |
# | ----------------------------------- | ----------- | ------------------------------------------------------------------------- |
# | `surface_reelle_bati`                                       | 59 %        | Critique pour calcul prix/m² → **filtrer les lignes nulles**   |
# | `nombre_pieces_principales`, `code_type_local`              | 43 %        | Même traitement : **supprimer ou étudier si remplaçables**     |
# | `adresse_numero`, `surface_terrain` | 30–40 %     | Peu critiques → à **garder si utiles**, sinon ignorer                     |
#
#
# 3. Colonnes faiblement incomplètes (< 5%)
#
# | Colonne                                              | Taux de NaN | Action                                                       |
# | ---------------------------------------------------- | ----------- | ------------------------------------------------------------ |
# | `valeur_fonciere`, `code_postal`, `adresse_nom_voie` | < 2%        | Très exploitables → **conserver**, filtrer les NaN à l’usage |
# | `latitude`, `longitude`             | 3.1 %       | Géolocalisation très utile → **garder**, filtrer les nulls ponctuellement |

# %%
# Types de données des colonnes
df.dtypes.value_counts().reset_index().rename(columns={
    'index': 'Type de donnée',
    0: 'Nombre de colonnes'
})
# Out:
#    Type de donnée  count
# 0          object     20
# 1         float32     17
# 2           int32      2
# 3  datetime64[ns]      1

# %%
df.dtypes.reset_index().rename(columns={'index': 'Colonne', 0: 'Type de donnée'})
# Out:
#                          Colonne  Type de donnée
# 0                    id_mutation          object
# 1                  date_mutation  datetime64[ns]
# 2             numero_disposition           int32
# 3                nature_mutation          object
# 4                valeur_fonciere         float32
# 5                 adresse_numero         float32
# 6                adresse_suffixe          object
# 7               adresse_nom_voie          object
# 8              adresse_code_voie          object
# 9                    code_postal         float32
# 10                  code_commune          object
# 11                   nom_commune          object
# 12              code_departement          object
# 13           ancien_code_commune         float32
# 14            ancien_nom_commune          object
# 15                   id_parcelle          object
# 16            ancien_id_parcelle          object
# 17                 numero_volume          object
# 18                   lot1_numero          object
# 19           lot1_surface_carrez         float32
# 20                   lot2_numero          object
# 21           lot2_surface_carrez         float32
# 22                   lot3_numero          object
# 23           lot3_surface_carrez         float32
# 24                   lot4_numero         float32
# 25           lot4_surface_carrez         float32
# 26                   lot5_numero         float32
# 27           lot5_surface_carrez         float32
# 28                   nombre_lots           int32
# 29               code_type_local         float32
# 30                    type_local          object
# 31           surface_reelle_bati         float32
# 32     nombre_pieces_principales         float32
# 33           code_nature_culture          object
# 34                nature_culture          object
# 35  code_nature_culture_speciale          object
# 36       nature_culture_speciale          object
# 37               surface_terrain         float32
# 38                     longitude         float32
# 39                      latitude         float32

# %%
### visualisation des répartitions des données numériques
# Sélection des colonnes numériques (hors ID ou géo)
num_cols = df.select_dtypes(include=['int32', 'float32']).columns.tolist()
num_cols = [col for col in num_cols if col not in ['longitude', 'latitude']]  # à exclure si besoin
num_cols
# Out:
# ['numero_disposition',
#  'valeur_fonciere',
#  'adresse_numero',
#  'code_postal',
#  'ancien_code_commune',
#  'lot1_surface_carrez',
#  'lot2_surface_carrez',
#  'lot3_surface_carrez',
#  'lot4_numero',
#  'lot4_surface_carrez',
#  'lot5_numero',
#  'lot5_surface_carrez',
#  'nombre_lots',
#  'code_type_local',
#  'surface_reelle_bati',
#  'nombre_pieces_principales',
#  'surface_terrain']

# %%
df['valeur_fonciere_log'] = np.log1p(df['valeur_fonciere'])
sns.histplot(df['valeur_fonciere_log'], bins=50)
plt.title("Log(valeur foncière + 1)")
plt.show()

# %%
# Affichage groupé des histogrammes
n = len(num_cols)
n_cols = 3
n_rows = (n // n_cols) + 1

plt.figure(figsize=(n_cols * 5, n_rows * 4))

for i, col in enumerate(num_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.histplot(df[col].dropna(), bins=20, kde=False)
    plt.title(col)
    plt.tight_layout()

# %%
# Liste des colonnes à supprimer (remplissage < 10%)
cols_to_drop_1 = [
    'ancien_code_commune', 'ancien_nom_commune', 'ancien_id_parcelle',
    'lot1_numero', 'lot1_surface_carrez', 'lot2_numero', 'lot2_surface_carrez',
    'lot3_numero', 'lot3_surface_carrez', 'lot4_numero', 'lot4_surface_carrez',
    'lot5_numero', 'lot5_surface_carrez'
]
# Suppression des colonnes
df = df.drop(columns=cols_to_drop_1, axis=1)

# Vérification des colonnes restantes
print(f"Shape after dropping columns: {df.shape}")
# Out:
# Shape after dropping columns: (3522416, 27)

# %%
# Liste des colonnes avec infos inutiles
cols_to_drop_2 = [
    'numero_disposition', 'adresse_numero', 'adresse_suffixe',
    'adresse_nom_voie', 'adresse_code_voie', 'nom_commune','nature_culture_speciale',
    'numero_volume', 'code_nature_culture', 'nature_culture','code_nature_culture_speciale'
]
df = df.drop(columns=cols_to_drop_2, axis=1)
print(f"Shape after dropping more columns: {df.shape}")
# Out:
# Shape after dropping more columns: (3522416, 16)

# %% [markdown]
# ## Etude des variables catégorielles

# %%
cat_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
cat_cols = [col for col in cat_cols if col not in ['id_mutation', 'id_parcelle']] 
print(f"{len(cat_cols)} colonnes catégorielles :")
print(cat_cols)
# Out:
# 4 colonnes catégorielles :
# ['nature_mutation', 'code_commune', 'code_departement', 'type_local']

# %%
# Répartition
for col in cat_cols:
    print(f"\n--- {col} ---")
    print(df[col].value_counts(dropna=False).head(10))
# Out:
# --- nature_mutation ---
# nature_mutation
# Vente                                 3207859
# Vente en l'état futur d'achèvement     254978
# Echange                                 37446
# Adjudication                            10270
# Vente terrain à bâtir                    9646
# Expropriation                            2217
# Name: count, dtype: int64
#
# --- code_commune ---
# code_commune
# 31555    28306
# 06088    17912
# 34172    16406
# 44109    14737
# 33063    13011
# 59350    11536
# 35238     9740
# 21231     9017
# 69266     8718
# 30189     8638
# Name: count, dtype: int64
#
# --- code_departement ---
# code_departement
# 59    94068
# 33    91946
# 69    84847
# 44    82786
# 13    82486
# 31    78854
# 83    74932
# 34    74464
# 92    73735
# 06    70750
# Name: count, dtype: int64
#
# --- type_local ---
# type_local
# nan                                         1537962
# Maison                                       706474
# Appartement                                  599623
# Dépendance                                   552111
# Local industriel. commercial ou assimilé     126246
# Name: count, dtype: int64

# %%
# Nombre max de modalités à afficher
max_modalities = 30

for col in cat_cols:
    nb_modalities = df[col].nunique()
    if nb_modalities <= max_modalities:
        plt.figure(figsize=(10, 4))
        sns.countplot(data=df, x=col, order=df[col].value_counts().index)
        plt.title(f"Répartition des modalités – {col}")
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()

# %%
sns.countplot(data=df, y="nature_mutation", order=df["nature_mutation"].value_counts().index)
plt.title("Répartition des types de mutation")
plt.xlabel("Nombre de mutations")
plt.ylabel("Type")
plt.show()

# %%
# Prix médian selon la nature de mutation
df.groupby("nature_mutation")["valeur_fonciere"].median().sort_values(ascending=False).plot(kind='barh')
plt.title("Prix médian selon le type de mutation")
plt.xlabel("Valeur foncière (€)")
plt.show()

# %%
 # Surface moyenne selon la nature de mutation
df.groupby("nature_mutation")["surface_reelle_bati"].mean().sort_values(ascending=False).plot(kind='barh')
plt.title("Surface moyenne selon le type de mutation")
plt.xlabel("Surface (m²)")
plt.ylabel("Nature de mutation")
# affichage de la surface moyenne maximum selon la nature de mutataion sur le graphique
plt.axvline(df["surface_reelle_bati"].mean(), color='red', linestyle='--', label='Surface moyenne')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='nature_mutation', y='valeur_fonciere')
plt.yscale('log')  # échelle logarithmique pour compresser les outliers
plt.xticks(rotation=45)
plt.title("Valeur foncière par type de mutation")
plt.ylabel("Valeur foncière (€)")
plt.xlabel("Nature de la mutation")
plt.tight_layout()
plt.show()

# %% [markdown]
# - **Vente en l'état futur d'achèvement** (VEFA) a un prix médian légèrement plus élevé que la vente classique.
#
# - **Expropriations** et **échanges** ont des valeurs foncières nettement plus basses en général.
#
# - La dispersion est énorme, surtout pour les **ventes** (avec des outliers dépassant 10⁷ €).
#
# On va maintenant étudier la distribution des ventes

# %%
mask = df["nature_mutation"] == "Vente"
cols = ['nature_mutation', 'valeur_fonciere', 'surface_reelle_bati', 'surface_terrain',
        'type_local', 'nom_commune', 'latitude', 'longitude']
df_vente = df.loc[mask, cols].copy()  

print(f"{len(df_vente):,} enregistrements")
# Out:
# 3,207,859 enregistrements

# %%
df_vente.describe(include='all').T
# Out:
#                          count unique       top     freq         mean  \
# nature_mutation        3207859      1     Vente  3207859          NaN
# valeur_fonciere      3159543.0    NaN       NaN      NaN    824473.75
# surface_reelle_bati  1373437.0    NaN       NaN      NaN   114.126564
# surface_terrain      2339544.0    NaN       NaN      NaN  2885.466797
# type_local             3207859      5       nan  1327220          NaN
# nom_commune            3207859  30570  Toulouse    21301          NaN
# latitude             3110824.0    NaN       NaN      NaN    46.048759
# longitude            3110824.0    NaN       NaN      NaN     2.340691
#
#                               std        min        25%        50%        75%  \
# nature_mutation               NaN        NaN        NaN        NaN        NaN
# valeur_fonciere         8002477.5       0.01    63000.0   147817.0   270000.0
# surface_reelle_bati    789.508911        1.0       50.0       76.0      107.0
# surface_terrain      16732.226562        1.0      233.0      605.0     1751.0
# type_local                    NaN        NaN        NaN        NaN        NaN
# nom_commune                   NaN        NaN        NaN        NaN        NaN
# latitude                 6.272769 -21.385195  44.686951  46.736755  48.651783
# longitude                6.581396 -63.142002   0.223788   2.339219   4.540971
#
#                              max
# nature_mutation              NaN
# valeur_fonciere      490000000.0
# surface_reelle_bati     218290.0
# surface_terrain       10723091.0
# type_local                   NaN
# nom_commune                  NaN
# latitude               51.086452
# longitude              55.829227

# %%
# séparation entre métropole et hors métropole
# Détection des zones hors métropole
df_vente["zone_geo"] = "Métropole"
df_vente.loc[df["latitude"] < 41, "zone_geo"] = "DROM/COM"

# %%
df_vente.head()
# Out:
#   nature_mutation  valeur_fonciere  surface_reelle_bati  surface_terrain  \
# 0           Vente           8000.0                  NaN           1061.0
# 1           Vente           2175.0                  NaN             85.0
# 2           Vente           2175.0                  NaN           1115.0
# 3           Vente           2175.0                  NaN           1940.0
# 4           Vente           2175.0                  NaN           1148.0
#
#   type_local nom_commune   latitude  longitude   zone_geo
# 0        nan   Ceyzériat  46.171940   5.323532  Métropole
# 1        nan        Laiz  46.251858   4.893454  Métropole
# 2        nan        Laiz  46.235275   4.900210  Métropole
# 3        nan        Laiz  46.246555   4.882112  Métropole
# 4        nan        Laiz  46.251842   4.894481  Métropole
